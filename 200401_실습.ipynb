# %%
b = '20010331Rainy'
print(b[:8]) # = print(b[0:8])
# Out:
# 20010331

# %%
print(b[:-1])
# Out:
# 20010331Rain

# %%
#문자열 수정
a = 'this is a string'

# %%
c = a.replace('string', 'rope') #변수 값을 바꾸지 않으면 자기자신은 변화 없음
c
# Out:
# 'this is a rope'

# %%
a = 'Korean culture'

# %%
a.count('ul')
# Out:
# 1

# %%
a.find('u')
# Out:
# 8

# %%
a.find('e') #첫 번째 걸리는 것만 잡는다.
# Out:
# 3

# %%
a.find('k') #값이 없을땐 -가 나옴
# Out:
# -1

# %%
b = '   Korean culture   '
b.strip()
# Out:
# 'Korean culture'

# %%
c = "Korean & American & Chinese"
c.split("&")
# Out:
# ['Korean ', ' American ', ' Chinese']
