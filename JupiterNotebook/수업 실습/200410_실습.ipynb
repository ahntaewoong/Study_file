# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.arange(1,11)
y = 2*x+5
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y axis caption")
plt.plot(x,y,'bo')
plt.show()

# %%
x = [1,2,3,4,5,6,7,8,9]
y1 = [1,3,5,3,1,3,5,3,1]
y2 = [2,4,6,4,2,4,6,4,2]
plt.plot(x, y1, 'go--', label="line L")
plt.plot(x, y2, 'bo--', label="line H")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Line Graph Example")
plt.show()

# %%
student_score = [
 [1, 90, 80, 85, 0, 0.0, 0, 0],
 [2, 88, 85, 90, 0, 0.0, 0, 0],
 [3, 32, 85, 90, 0, 0.0, 0, 0],
 [4, 42, 75, 93, 0, 0.0, 0, 0],
 [5, 82, 86, 88, 0, 0.0, 0, 0]
]
student_score
# Out:
# [[1, 90, 80, 85, 0, 0.0, 0, 0],
#  [2, 88, 85, 90, 0, 0.0, 0, 0],
#  [3, 32, 85, 90, 0, 0.0, 0, 0],
#  [4, 42, 75, 93, 0, 0.0, 0, 0],
#  [5, 82, 86, 88, 0, 0.0, 0, 0]]

# %%
type(student_score)
# Out:
# list

# %%
student_score = np.array(student_score)

# %%
student_score
# Out:
# array([[ 1., 90., 80., 85.,  0.,  0.,  0.,  0.],
#        [ 2., 88., 85., 90.,  0.,  0.,  0.,  0.],
#        [ 3., 32., 85., 90.,  0.,  0.,  0.,  0.],
#        [ 4., 42., 75., 93.,  0.,  0.,  0.,  0.],
#        [ 5., 82., 86., 88.,  0.,  0.,  0.,  0.]])

# %%
x = ["kor", "eng", "math"]
x
# Out:
# ['kor', 'eng', 'math']

# %%
y1 = np.array(student_score[0][1:4])
y2 = np.array(student_score[1][1:4])
y3 = np.array(student_score[2][1:4])
y4 = np.array(student_score[3][1:4])
y5 = np.array(student_score[4][1:4])

# %%
y1
# Out:
# array([90., 80., 85.])

# %%
y2
# Out:
# array([88., 85., 90.])

# %%
y3
# Out:
# array([32., 85., 90.])

# %%
y4
# Out:
# array([42., 75., 93.])

# %%
y5
# Out:
# array([82., 86., 88.])

# %%
plt.plot(x, y1, 'bo--', label="student_1", color = "blue")
plt.plot(x, y2, 'bo--', label="student_2",color = "gray")
plt.plot(x, y3, 'bo--', label="student_3",color = "green")
plt.plot(x, y4, 'bo--', label="student_4",color = "red")
plt.plot(x, y5, 'bo--', label="student_5",color = "purple")
plt.xlabel("subject")
plt.ylabel("score")
plt.title("student_score")
plt.legend()
plt.show()

# %%
i=0
for i in range(len(student_score)):
  x=["kor","eng","math"]
  y=student_score[i][1:4] #1~3
  plt.plot(x,y,'o--')
  plt.xlabel("subject")
  plt.ylabel("score")
  plt.legend(['student1', 'student2', 'student3', 'student4', 'student5'])
  i+1
  plt.title("Students score")

# %%
x1=[1,3,4,5,6,7,9]
y1=[4,7,2,4,7,8,3]
x2=[2,4,6,8,10]  
y2=[5,6,2,6,2]
plt.bar(x1,y1,label="Blue Bar", color='b')
plt.bar(x2,y2,label="Green Bar", color='g')
plt.xlabel("bar number")
plt.ylabel("bar height")
plt.title("Bar chart Example")
plt.show()

# %%
student_score = [
 [1, 90, 80, 85, 0, 0.0, 0, 0],
 [2, 88, 85, 90, 0, 0.0, 0, 0],
 [3, 32, 85, 90, 0, 0.0, 0, 0],
 [4, 42, 75, 93, 0, 0.0, 0, 0],
 [5, 82, 86, 88, 0, 0.0, 0, 0]
]
student_score
# Out:
# [[1, 90, 80, 85, 0, 0.0, 0, 0],
#  [2, 88, 85, 90, 0, 0.0, 0, 0],
#  [3, 32, 85, 90, 0, 0.0, 0, 0],
#  [4, 42, 75, 93, 0, 0.0, 0, 0],
#  [5, 82, 86, 88, 0, 0.0, 0, 0]]

# %%
student_score = np.array(student_score)

# %%
label = ['student1','student2', 'student3','student4','student5']
y1 = np.array(student_score[:,1])
y2 = np.array(student_score[:,2])
y3 = np.array(student_score[:,3])

# %%
x
# Out:
# ['student1', 'student2', 'student3', 'student4', 'student5']

# %%
y1
# Out:
# array([90., 88., 32., 42., 82.])

# %%
y2
# Out:
# array([80., 85., 85., 75., 86.])

# %%
label = ['student1','student2', 'student3','student4','student5']
y1 = np.array(student_score[:,1])
y2 = np.array(student_score[:,2])
y3 = np.array(student_score[:,3])

x = np.arange(len(label))


plt.bar(x-0.2, y1, label="kor", color='b', width=0.2)
plt.bar(x, y2, label="eng", color='g', width=0.2)
plt.bar(x+0.2, y3, label="math", color='r', width=0.2)
plt.xlabel("student")
plt.ylabel("score")
plt.title("student_score")
plt.xticks(x,label)
plt.legend()
plt.show()

# %%
n = 5 + np.random.randn(1000)
m = [m for m in range(len(n))]
plt.bar(m,n)
plt.title("Raw Data")
plt.show()

# %%
plt.hist(n,bins=20)
plt.title("Histogram")
plt.show()

# %%
plt.hist(n,cumulative = True, bins=20)
plt.title("Cumulative Histogram")
plt.show()

# %%
x1 = [2,3,4]
y1 = [5,5,5]
x2 = [1,2,3,4,5]
y2 = [2,3,2,3,4]
y3 = [6,8,7,8,7]
plt.scatter(x1,y1)
plt.scatter(x2,y2,marker='v', color = 'r')
plt.scatter(x2,y3,marker='^', color = 'm')
plt.title('Scatter Plot Example')
plt.show()
