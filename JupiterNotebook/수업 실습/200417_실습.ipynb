# %%
import requests
from bs4 import BeautifulSoup

# %%
info_url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109'

# %%
response = requests.get(info_url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
locations = soup.find_all('location')

# %%
locations

# %%
for location in locations:
    print(location.find('city').text, ":", location.find('wf').text)

# %%
url = 'http://finance.daum.net/api/market_index/days?page=1&perPage=100&market=KOSPI&pagination=true'
header = {'Referer' :'http://finance.daum.net/domestic/kospi',
          'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}

# %%
r3 = requests.get(url, headers = header)

# %%
import json

# %%
rt_dict = json.loads(r3.content)
rt_dict
# Out:
# {'currentPage': 1,
#  'data': [{'accTradePrice': 8027050,
#    'accTradeVolume': 1046354,
#    'change': 'RISE',
#    'changePrice': 64.5,
#    'date': '2020-04-17 00:00:00',
#    'foreignStraightPurchasePrice': 472084636767,
#    'individualStraightPurchasePrice': -695688456331,
#    'institutionStraightPurchasePrice': 203195978016,
#    'tradePrice': 1921.57},
#   {'accTradePrice': 10710793,
#    'accTradeVolume': 878338,
#    'change': 'FALL',
#    'changePrice': 0.01,
#    'date': '2020-04-16 00:00:00',
#    'foreignStraightPurchasePrice': -568747434203,
#    'individualStraightPurchasePrice': 388811930906,
#    'institutionStraightPurchasePrice': 136273588590,
#    'tradePrice': 1857.07},
#   {'accTradePrice': 9995854,
#    'accTradeVolume': 886766,
#    'change': 'RISE',
#    'changePrice': 31.32,
#    'date': '2020-04-14 00:00:00',
#    'foreignStraightPurchasePrice': -31749385164,
#    'individualStraightPurchasePrice': -453035680022,
# ...

# %%
rt_dict.keys()
# Out:
# dict_keys(['data', 'totalPages', 'currentPage', 'pageSize'])

# %%
import pandas as pd

# %%
pd.DataFrame(rt_dict['data'])
# Out:
#                    date  ...  institutionStraightPurchasePrice
# 0   2020-04-17 00:00:00  ...                      203195978016
# 1   2020-04-16 00:00:00  ...                      136273588590
# 2   2020-04-14 00:00:00  ...                      467937939436
# 3   2020-04-13 00:00:00  ...                     -457552761800
# 4   2020-04-10 00:00:00  ...                     -205919589435
# ..                  ...  ...                               ...
# 95  2019-11-28 00:00:00  ...                       72029926788
# 96  2019-11-27 00:00:00  ...                       94186142189
# 97  2019-11-26 00:00:00  ...                      763069951315
# 98  2019-11-25 00:00:00  ...                      358914415593
# 99  2019-11-22 00:00:00  ...                       91181180853
#
# [100 rows x 9 columns]

# %%
import time

# %%
url = 'https://openapi.naver.com/v1/search/news.json?query=스마트'

# %%
header = {'X-Naver-Client-Id': 'F3utKgejN9nVA6P2f31N', 'X-Naver-Client-Secret':'TnoosLPwRX'}

# %%
r3 = requests.get(url, headers = header)

# %%
r3.status_code
# Out:
# 200

# %%
soup_news = BeautifulSoup(r3.content, 'html.parser')

# %%
type(soup_news), soup_news
# Out:
# (bs4.BeautifulSoup, {
#  "lastBuildDate": "Fri, 17 Apr 2020 12:48:36 +0900",
#  "total": 4271021,
#  "start": 1,
#  "display": 10,
#  "items": [
#  {
#  "title": "[의정부] 첫 민간 개발사업 을지대병원 내년 3월 개원",
#  "originallink": "http://www.newscj.com/news/articleView.html?idxno=729196",
#  "link": "http://www.newscj.com/news/articleView.html?idxno=729196",
#  "description": "문화생활과 의료문화 복합 공간 <b>스마트</b>병원 구축할 양해각서 체결 경기도 의정부시가 첫 민간 개발사업... 인공지능 <b>스마트</b>병원(AI-EMC) 구축에 대한 양해각서(MOU)를 체결했다. 양해각서의 주요 내용은 ▲<b>스마트</b>병원... ",
#  "pubDate": "Fri, 17 Apr 2020 12:46:00 +0900"
#
#  },
#  {
#  "title": "코로나19 슬기로운 자발적 격리생활! 목뒤가 뻐근하다면?",
#  "originallink": "http://www.wikitree.co.kr/articles/524550",
#  "link": "http://www.wikitree.co.kr/articles/524550",
#  "description": "최근에는 <b>스마트</b>폰 장시간 사용으로 인해 젊은 층에서도 목 디스크가 증가하는 추세이다. 디스크가... 대동병원 척추센터 문종욱 과장(정형외과 전문의)은 “코로나19로 여가 생활이 줄어들면서 집에서 <b>스마트</b>폰이나... ",
#  "pubDate": "Fri, 17 Apr 2020 12:44:00 +0900"
#
#  },
#  {
# ...

# %%
soup_news.find_all('title')
# Out:
# []

# %%
r3.text, type(r3.text)
# Out:
# ('{\n"lastBuildDate": "Fri, 17 Apr 2020 12:41:21 +0900",\n"total": 4271015,\n"start": 1,\n"display": 10,\n"items": [\n{\n"title": "여의도성모, 대학병원 첫 비(非)대면 \'간호사 채용\'",\n"originallink": "http://www.dailymedi.com/detail.php?number=855237&thread=22r02",\n"link": "http://www.dailymedi.com/detail.php?number=855237&thread=22r02",\n"description": "온라인 화상면접 대상자는 총 163명으로, 지원자들은 PC나 <b>스마트</b>폰, 테블릿 등을 활용해 지정된 시간에 독립된 공간에서 5분 이내의 화상 면접에 참가했다.\xa0\xa0의료기관 화상면접은 이번이 첫 사례는 아니다. 앞서... ",\n"pubDate": "Fri, 17 Apr 2020 12:40:00 +0900"\n\n},\n{\n"title": "충남도, IoT 기술 활용한 <b>스마트</b> 홍수관리시스템 구축",\n"originallink": "http://www.cctvnews.co.kr/news/articleView.html?idxno=200755",\n"link": "http://www.cctvnews.co.kr/news/articleView.html?idxno=200755",\n"description": "된 <b>스마트</b> 홍수관리시스템을 구축한다.도는 올해 국비 24억 5000만 원, 도비 9억 5000만 원을 투자해 논산시와 서천군에 홍수관리시스템을 구축한다고 17일 밝혔다. <b>스마트</b> 홍수관리시스템은 상황실에서 하천 수문을... ",\n"pubDate": "Fri, 17 Apr 2020 12:39:00 +0900"\n\n},\n{\n"title": "[드링킷] 엄지족을 위한 유용한 술 관련 어플",\n"origina
# ...
