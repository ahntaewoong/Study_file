# %%
pip install pandas

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
os.getcwd()

# %%
os.chdir(os.getcwd()+'/drive')

# %%
os.path.exists('../drive/My Drive/Test/titanic.csv.xlsx')

# %%
titanic = pd.read_excel('../drive/My Drive/Test/titanic.csv.xlsx')
titanic

# %%
type(titanic)

# %%
titanic.head()

# %%
titanic.head(10)

# %%
titanic.shape

# %%
titanic.isnull().sum()

# %%
titanic

# %%
titanic["Age"].fillna(titanic.groupby("Sex")["Age"].transform("mean"), inplace=True)

# %%
titanic.isnull().sum()

# %%
titanic

# %%
titanic[titanic.Survived == 1]

# %%
titanic[titanic.Survived == 0]
