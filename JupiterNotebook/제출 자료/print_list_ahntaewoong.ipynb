# %%
movies = ["The Holy Grail", "The Life of Brian", "The Meaning of Life"]

# %%
for x in movies:
  print(x)
# Out:
# The Holy Grail
# The Life of Brian
# The Meaning of Life

# %%
def printmovie(name):
  for i in name:
    print(i)
  return

# %%
printmovie(movies)
# Out:
# The Holy Grail
# The Life of Brian
# The Meaning of Life
