# %%
movies = ['The Holy Grail', 1975, 'The Life of Brian', 91, ['Graham cahpman',['Michael Palin', 'John Cleese', 'Terry Giliam', 'Eric Idel']]]
for each_item in movies:
    print(each_item)
# Out:
# The Holy Grail
# 1975
# The Life of Brian
# 91
# ['Graham cahpman', ['Michael Palin', 'John Cleese', 'Terry Giliam', 'Eric Idel']]

# %%
isinstance(movies, list)
# Out:
# True

# %%
for each_item in movies:
    if isinstance(each_item, list):
        for x in each_item:
            if isinstance(x, list):
                for y in x:
                  print(y)
            else:
                print(x)
    else:
        print(each_item)
# Out:
# The Holy Grail
# 1975
# The Life of Brian
# 91
# Graham cahpman
# Michael Palin
# John Cleese
# Terry Giliam
# Eric Idel
