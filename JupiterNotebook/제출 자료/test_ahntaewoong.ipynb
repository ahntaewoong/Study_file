# %%
myage = input('What is your age?')
age = int(myage) 
print("Your age is " +str(age))
# Out:
# What is your age?31
# Your age is 31

# %%
str = 'Hello world!'
str
# Out:
# 'Hello world!'

# %%
str[0] #컴퓨터에서의 순서는 0번부터
# Out:
# 'H'

# %%
str[2:6] #6번째는 빠짐
# Out:
# 'llo '

# %%
str[2:]
# Out:
# 'llo world!'

# %%
str*2
# Out:
# 'Hello world!Hello world!'

# %%
str + "TEST"
# Out:
# 'Hello world!TEST'

# %%
list = ['abcd', 786, 2.33, 'john', 70.2]

# %%
tinylist = [123, 'john']

# %%
list
# Out:
# ['abcd', 786, 2.33, 'john', 70.2]

# %%
list[0]
# Out:
# 'abcd'

# %%
list[1:3]
# Out:
# [786, 2.33]

# %%
list[2:]
# Out:
# [2.33, 'john', 70.2]

# %%
tinylist*2
# Out:
# [123, 'john', 123, 'john']

# %%
list+tinylist
# Out:
# ['abcd', 786, 2.33, 'john', 70.2, 123, 'john']

# %%
list[0]+tinylist[1]
# Out:
# 'abcdjohn'

# %%
list = ['lion', 'eagle', 'bear']

# %%
list[2]
# Out:
# 'bear'

# %%
del list[2]

# %%
list
# Out:
# ['lion', 'eagle']

# %%
Baseball = ['LG', 'KIWOOM', 'DOOSAN', 'SK', 'NC']

# %%
Baseball[0]
# Out:
# 'LG'

# %%
del Baseball[2]

# %%
Baseball
# Out:
# ['LG', 'KIWOOM', 'SK', 'NC']
