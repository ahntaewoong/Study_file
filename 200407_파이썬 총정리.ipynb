# %%
students_list = [
 [1, 90, 80, 85, 0, 0.0, 0],
 [2, 90, 85, 90, 0, 0.0, 0],
 [3, 80, 80, 80, 0, 0.0, 0]
]

# %%
students_dict = [
{'num':'1', 'name':'김철수','kor':90, 'eng':80, 'math':85},
{'num':'2', 'name':'박제동','kor':90, 'eng':85, 'math':90},
{'num':'3', 'name':'홍길동','kor':80,' eng':80, 'math':80}
]

# %%
students_list, students_dict
# Out:
# ([[1, 90, 80, 85, 0, 0.0, 0],
#   [2, 90, 85, 90, 0, 0.0, 0],
#   [3, 80, 80, 80, 0, 0.0, 0]],
#  [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#   {'eng': 85, 'kor': 90, 'math': 90, 'name': '박제동', 'num': '2'},
#   {' eng': 80, 'kor': 80, 'math': 80, 'name': '홍길동', 'num': '3'}])

# %% [markdown]
# # Indexing

# %%
students_list[0], students_dict[0]
# Out:
# ([1, 90, 80, 85, 0, 0.0, 0],
#  {'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'})

# %%
students_list[0][1], students_dict[0]['name']
# Out:
# (90, '김철수')

# %% [markdown]
# # Slicing

# %%
students_list[:3], students_dict[:-1]
# Out:
# ([[1, 90, 80, 85, 0, 0.0, 0],
#   [2, 90, 85, 90, 0, 0.0, 0],
#   [3, 80, 80, 80, 0, 0.0, 0]],
#  [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#   {'eng': 85, 'kor': 90, 'math': 90, 'name': '박제동', 'num': '2'}])

# %% [markdown]
# # Update

# %%
students_list[1], students_dict[2]
# Out:
# ([2, 90, 85, 90, 0, 0.0, 0],
#  {' eng': 80, 'kor': 80, 'math': 80, 'name': '홍길동', 'num': '3'})

# %%
# row
students_list[1] = [1, 95, 89, 88, 0, 0.0, 0]
students_dict[2] = {'num':'1', 'name':'김철수','kor':96, 'eng':83, 'math':92}
students_list[1], students_dict[2]
# Out:
# ([1, 95, 89, 88, 0, 0.0, 0],
#  {'eng': 83, 'kor': 96, 'math': 92, 'name': '김철수', 'num': '1'})

# %%
# column
students_list[1][2] = 92
students_dict[2]['eng'] = 94
students_list[1], students_dict[2]
# Out:
# ([1, 95, 92, 88, 0, 0.0, 0],
#  {'eng': 94, 'kor': 96, 'math': 92, 'name': '김철수', 'num': '1'})

# %% [markdown]
# # Delete

# %%
students_list, students_dict
# Out:
# ([[1, 90, 80, 85, 0, 0.0, 0],
#   [1, 95, 92, 88, 0, 0.0, 0],
#   [3, 80, 80, 80, 0, 0.0, 0]],
#  [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#   {'eng': 85, 'kor': 90, 'math': 90, 'name': '박제동', 'num': '2'},
#   {'eng': 94, 'kor': 96, 'math': 92, 'name': '김철수', 'num': '1'}])

# %%
# row
del students_list[1]
del students_dict[2]
students_list, students_dict
# Out:
# ([[1, 90, 80, 85, 0, 0.0, 0], [3, 80, 80, 80, 0, 0.0, 0]],
#  [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#   {'eng': 85, 'kor': 90, 'math': 90, 'name': '박제동', 'num': '2'}])

# %%
# column
del students_list[0][0]
del students_dict[1]['name']
students_list, students_dict, len(students_dict)
# Out:
# ([[90, 80, 85, 0, 0.0, 0], [3, 80, 80, 80, 0, 0.0, 0]],
#  [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#   {'eng': 85, 'kor': 90, 'math': 90, 'num': '2'}],
#  2)

# %% [markdown]
# # insert & append

# %%
students_list.insert(0, [1, 90, 80, 85, 0, 0.0, 0])
students_dict.insert(len(students_dict), {'eng': 94, 'kor': 96, 'math': 92, 'name': '김철수', 'num': '4'})
students_list, students_dict
# Out:
# ([[1, 90, 80, 85, 0, 0.0, 0],
#   [90, 80, 85, 0, 0.0, 0],
#   [3, 80, 80, 80, 0, 0.0, 0]],
#  [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#   {'eng': 85, 'kor': 90, 'math': 90, 'num': '2'},
#   {'eng': 94, 'kor': 96, 'math': 92, 'name': '김철수', 'num': '4'}])

# %%
students_list[0].insert(0, 30)
students_dict[2]['temp']= 30
students_list, students_dict
# Out:
# ([[30, 1, 90, 80, 85, 0, 0.0, 0],
#   [90, 80, 85, 0, 0.0, 0],
#   [3, 80, 80, 80, 0, 0.0, 0]],
#  [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#   {'eng': 85, 'kor': 90, 'math': 90, 'num': '2'},
#   {'eng': 94, 'kor': 96, 'math': 92, 'name': '김철수', 'num': '4', 'temp': 30}])

# %% [markdown]
# # for 문

# %%
for item in students_list:
    print(item, type(item))
# Out:
# [30, 1, 90, 80, 85, 0, 0.0, 0] <class 'list'>
# [90, 80, 85, 0, 0.0, 0] <class 'list'>
# [3, 80, 80, 80, 0, 0.0, 0] <class 'list'>

# %%
for item in students_dict:
    print(item, type(item))
# Out:
# {'num': '1', 'name': '김철수', 'kor': 90, 'eng': 80, 'math': 85} <class 'dict'>
# {'num': '2', 'kor': 90, 'eng': 85, 'math': 90} <class 'dict'>
# {'eng': 94, 'kor': 96, 'math': 92, 'name': '김철수', 'num': '4', 'temp': 30} <class 'dict'>
