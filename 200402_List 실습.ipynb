# %%
cast = ["Cleese", "Palin", 34.52, 'Idle', "Cleese"]
print(cast[2], cast[-2], cast[1:])
# Out:
# 34.52 Idle ['Palin', 34.52, 'Idle', 'Cleese']

# %%
cast.append('Gilliam')
cast
# Out:
# ['Cleese', 'Palin', 34.52, 'Idle', 'Cleese', 'Gilliam']

# %%
cast.count("Cleese")
# Out:
# 2

# %%
cast.extend(['Idle', 'Gilliam'])
cast
# Out:
# ['Cleese', 'Palin', 34.52, 'Idle', 'Cleese', 'Gilliam', 'Idle', 'Gilliam']

# %%
cast.pop()
# Out:
# 'Gilliam'

# %%
cast
# Out:
# ['Cleese', 'Palin', 34.52, 'Idle', 'Cleese', 'Gilliam', 'Idle']

# %%
cast.insert(0, 'Cleese')
cast
# Out:
# ['Cleese', 'Cleese', 'Palin', 34.52, 'Idle', 'Cleese', 'Gilliam', 'Idle']

# %%
cast.remove('Cleese')

# %%
cast
# Out:
# ['Palin', 34.52, 'Idle', 'Gilliam', 'Idle']

# %%
cast.reverse()

# %%
cast
# Out:
# ['Idle', 'Gilliam', 'Idle', 34.52, 'Palin']

# %%
movies = ["The Holy Grail", "The Life of Brian", "The Meaning of Life"]
print(movies)
# Out:
# ['The Holy Grail', 'The Life of Brian', 'The Meaning of Life']

# %%
movies.insert(1, 1975)
movies.insert(3, 1979)
movies.insert(5, 1983)
print(movies)
# Out:
# ['The Holy Grail', 1975, 'The Life of Brian', 1979, 'The Meaning of Life', 1983]

# %%
movies.remove(1983)

# %%
print(movies)
# Out:
# ['The Holy Grail', 1975, 'The Life of Brian', 1979, 'The Meaning of Life']

# %%
movies = ['The Holy Grail', 1975, 'The Life of Brian', 91, ['Graham Cahpman',['Micheal Palin', 'John Cleese', 'Terry Gilliam', 'Eric Idle']]]
print(movies[4][1][2])
# Out:
# Terry Gilliam

# %%
isinstance(movies, list)
# Out:
# True
