# %%
# Function                    함수는 메뉴얼과 연결    변수는 데이터와 연결

# %%
def print_info(name, age = 35):
    print("name", name)
    print("age", age)
    return;

# %%
    print_info(age = 31, name = "ahntaewoong")
# Out:
# name ahntaewoong
# age 31

# %%
print_info(name = "ahntaewoong")
# Out:
# name ahntaewoong
# age 35

# %%
print_info(age = 100, name = "LG")
# Out:
# name LG
# age 100

# %%
print_info(name = "OB")
# Out:
# name OB
# age 35

# %%
def print(name, age = 35):
    print("name", name)
    print("age", age)
    return;

# %%
print()   #기존에 있었던 이름과 겹치기 때문에 에러
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-68d0a8ad6c69> in <module>()
# ----> 1 print()
#
# TypeError: print() missing 1 required positional argument: 'name'

# %%
def sum(arg1, arg2):
    result = arg1 + arg2
    print("Inside the function : ", result)
    return result

# %%
total = sum(10, 20)
print("Outside the function :" , total)
# Out:
# Inside the function :  30
# Outside the function : 30

# %%
def changeme(fmylist):
    fmylist = [1,2,3,4];
    print("Values inside the function:", fmylist)
    return

# %%
mylist = [10,20,30];
changeme(mylist);
print("Values ouside the function:", mylist)
# Out:
# Values inside the function: [1, 2, 3, 4]
# Values ouside the function: [10, 20, 30]

# %%
def changeme(fmylist):
    fmylist.append([1,2,3,4]);
    print("Values inside the function:", fmylist)
    return

# %%
mylist = [10,20,30];
changeme(mylist);
print("Values ouside the function:", mylist)
# Out:
# Values inside the function: [10, 20, 30, [1, 2, 3, 4]]
# Values ouside the function: [10, 20, 30, [1, 2, 3, 4]]

# %%
def printinfo(fname, fage = 35):
    return fname, fage

# %%
name, age = printinfo(fage = 50, fname = "miki")
print(name + "," + str(age))
# Out:
# miki,50

# %%
print(name, age)
# Out:
# miki 50

# %%
def my_friend(friendName):
    print("{}는 나의 친구입니다.".format(friendName))

# %%
my_friend("철수")
my_friend("영희")
# Out:
# 철수는 나의 친구입니다.
# 영희는 나의 친구입니다.

# %%
def print_return_tuple(arg1, *vartuple):
    print("Inside arg1 is : ", arg1)
    for var in vartuple:
        print("Inside vartuple is : ", var)
    return vartuple

# %%
    print_return_tuple(10)
    out_tuple = print_return_tuple(70, 60, 50)
    print(out_tuple)
# Out:
# Inside arg1 is :  10
# Inside arg1 is :  70
# Inside vartuple is :  60
# Inside vartuple is :  50
# (60, 50)

# %%
def functionA(*var_args01, **var_args02):
    print(var_args01, type(var_args01))
    print(var_args02, type(var_args02))

functionA(1,2,3,4,5,6, a=2, b=3, c=5)
# Out:
# (1, 2, 3, 4, 5, 6) <class 'tuple'>
# {'a': 2, 'b': 3, 'c': 5} <class 'dict'>

# %%
args_list = [1,2,3,4]
args_dict = {'a': 10, 'b': 20}
functionA(*args_list, **args_dict)
# Out:
# (1, 2, 3, 4) <class 'tuple'>
# {'a': 10, 'b': 20} <class 'dict'>

# %%
age = int(input('how old are you?'))

print(age)
# Out:
# how old are you?31
# 31

# %%
age = int(input('how old are you?'))

print('I`m',age,'years old')
# Out:
# how old are you?31
# I`m 31 years old

# %%
str = 'Hello World!'

# %%
print(str)
# Out:
# Hello World!

# %%
print(str[0])
# Out:
# H

# %%
print(str[2:5])
# Out:
# llo

# %%
print(str[2:])
# Out:
# llo World!

# %%
print(str*2)
# Out:
# Hello World!Hello World!

# %%
print(str+"TEST")
# Out:
# Hello World!TEST

# %%
list = [ 'abcd', 786 , 2.23, 'john', 70.2 ]

tinylist = [123, 'john']

print(list)
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]

# %%
movies = ["The Holy Grail", "The Life of Brian", "The Meaning of Life"]

# %%
movies
# Out:
# ['The Holy Grail', 'The Life of Brian', 'The Meaning of Life']

# %%
movies[2]
# Out:
# 'The Meaning of Life'

# %%
dict = {}

dict['one'] = "This is one"

dict[2]     = "This is two"

tinydict = {'name': 'john','code':6734, 'dept': 'sales'}

print(dict['one'])
# Out:
# This is one

# %%
print(dict[2])
# Out:
# This is two

# %%
print(tinydict.keys())
# Out:
# dict_keys(['name', 'code', 'dept'])

# %%
print(tinydict.values())
# Out:
# dict_values(['john', 6734, 'sales'])

# %%
movies = ['The Holy Grail', 1975, 'The Life of Brian', 91, 

                     ['Graham Cahpman',['Michael Palin', 'John Cleese', 'Terry Gilliam', 'Eric Idle']]]

for each_item in movies:

  print(each_item)
# Out:
# The Holy Grail
# 1975
# The Life of Brian
# 91
# ['Graham Cahpman', ['Michael Palin', 'John Cleese', 'Terry Gilliam', 'Eric Idle']]
