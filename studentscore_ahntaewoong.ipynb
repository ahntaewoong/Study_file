# %%
students_score = [
                  {'num':'1', 'name': '김철수', 'kor' : 90, 'eng' : 80, 'math': 85},
                  {'num':'2', 'name': '박제동', 'kor' : 90, 'eng' : 85, 'math': 90},
                  {'num':'3', 'name': '홍길동', 'kor' : 80, 'eng' : 80, 'math': 80}
]

# %%
student_score = student_score +
# Out:
# [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': '1'},
#  {'eng': 85, 'kor': 90, 'math': 90, 'name': '박제동', 'num': '2'},
#  {'eng': 80, 'kor': 80, 'math': 80, 'name': '홍길동', 'num': '3'},
#  {'eng': 83, 'kor': 92, 'math': 100, 'name': '이천웅', 'num': '4'},
#  {'eng': 88, 'kor': 91, 'math': 92, 'name': '채은성', 'num': '5'}]

# %%
for x, y in enumerate(students_score):                  # 각 학생에 total, avg 구하기
    y['total'] = y['kor'] + y['eng'] + y['math']
    y['avg'] = (y['kor'] + y['eng'] + y['math']) / 3

# %%
students_score
# Out:
# [{'avg': 85.0,
#   'eng': 80,
#   'kor': 90,
#   'math': 85,
#   'name': '김철수',
#   'num': '1',
#   'total': 255},
#  {'avg': 88.33333333333333,
#   'eng': 85,
#   'kor': 90,
#   'math': 90,
#   'name': '박제동',
#   'num': '2',
#   'total': 265},
#  {'avg': 80.0,
#   'eng': 80,
#   'kor': 80,
#   'math': 80,
#   'name': '홍길동',
#   'num': '3',
#   'total': 240},
#  {'avg': 91.66666666666667,
#   'eng': 83,
#   'kor': 92,
#   'math': 100,
#   'name': '이천웅',
#   'num': '4',
#   'total': 275},
#  {'avg': 90.33333333333333,
#   'eng': 88,
#   'kor': 91,
#   'math': 92,
#   'name': '채은성',
#   'num': '5',
#   'total': 271}]

# %%
len(students_score)
# Out:
# 5

# %%
#학급 평균 구하기
x = []
for i in students_score:
  x.append(i.get('avg'))
print(x)
class_avg = sum(x)/len(students_score)
class_avg
# Out:
# [85.0, 88.33333333333333, 80.0, 91.66666666666667, 90.33333333333333]
# 87.06666666666666

# %%
# 과목별 평균 구하기 kor
x = []
for kor_score in students_score:
  x.append(kor_score.get('kor'))
print(x)
Kor_Avg = sum(x) / len(x)
Kor_Avg
# Out:
# [90, 90, 80, 92, 91]
# 88.6

# %%
# 과목별 평균 구하기 eng
x = []
for eng_score in students_score:
  x.append(eng_score.get('eng'))
print(x)
eng_Avg = sum(x) / len(x)
eng_Avg
# Out:
# [80, 85, 80, 83, 88]
# 83.2

# %%
# 과목별 평균 구하기 math
x = []
for math_score in students_score:
  x.append(math_score.get('math'))
print(x)
math_Avg = sum(x) / len(x)
math_Avg
# Out:
# [85, 90, 80, 100, 92]
# 89.4
